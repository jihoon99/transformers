# %%
# # GPU

# import tensorflow as tf

# device_name = tf.test.gpu_device_name()
# if device_name != '/device:GPU:0':
#     raise SystemError('GPU not found')
# print(f'Found GPU at : {device_name}')

# %%
import torch
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler

from tensorflow.keras.preprocessing.sequence import pad_sequences

from sklearn.model_selection import train_test_split

from transformers import BertTokenizer, BertConfig
from transformers import AdamW, BertForSequenceClassification, get_linear_schedule_with_warmup

from tqdm import tqdm, trange
import pandas as pd
import io
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-3-98dd023d36dd> in <module>
#       6 from sklearn.model_selection import train_test_split
#       7
# ----> 8 from transformers import BertTokenizer, BertConfig
#       9 from transformers import AdamW, BertForSequenceClassification, get_linear_schedule_with_warmup
#      10
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/__init__.py in _get_module(self, module_name)
#    3018
#    3019         def _get_module(self, module_name: str):
# -> 3020             return importlib.import_module("." + module_name, self.__name__)
#    3021
#    3022         def __getattr__(self, name: str):
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/__init__.py in <module>
#      17 # limitations under the License.
#      18
# ---> 19 from . import (
#      20     albert,
#      21     auto,
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/layoutlm/__init__.py in <module>
#      21 from ...file_utils import _BaseLazyModule, is_tf_available, is_tokenizers_available, is_torch_available
#      22 from .configuration_layoutlm import LAYOUTLM_PRETRAINED_CONFIG_ARCHIVE_MAP, LayoutLMConfig
# ---> 23 from .tokenization_layoutlm import LayoutLMTokenizer
#      24
#      25
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/layoutlm/tokenization_layoutlm.py in <module>
#      17
#      18 from ...utils import logging
# ---> 19 from ..bert.tokenization_bert import BertTokenizer
#      20
#      21
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/bert/tokenization_bert.py in <module>
#      21 from typing import List, Optional, Tuple
#      22
# ---> 23 from ...tokenization_utils import PreTrainedTokenizer, _is_control, _is_punctuation, _is_whitespace
#      24 from ...utils import logging
#      25
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/tokenization_utils.py in <module>
#      24
#      25 from .file_utils import PaddingStrategy, TensorType, add_end_docstrings
# ---> 26 from .tokenization_utils_base import (
#      27     ENCODE_KWARGS_DOCSTRING,
#      28     ENCODE_PLUS_ADDITIONAL_KWARGS_DOCSTRING,
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/tokenization_utils_base.py in <module>
#      67
#      68 if is_tokenizers_available():
# ---> 69     from tokenizers import AddedToken
#      70     from tokenizers import Encoding as EncodingFast
#      71 else:
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/__init__.py in <module>
#      77
#      78
# ---> 79 from .tokenizers import (
#      80     Tokenizer,
#      81     Encoding,
#
# ImportError: dlopen(/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so, 2): no suitable image found.  Did find:
# 	/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so: mach-o, but wrong architecture
# 	/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so: mach-o, but wrong architecture

# %%
import transformers

# %%
transformers.BertTokenizer
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-b5f120a5ee47> in <module>
# ----> 1 transformers.BertTokenizer
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/__init__.py in __getattr__(self, name)
#    3024             if name == "__version__":
#    3025                 return __version__
# -> 3026             return super().__getattr__(name)
#    3027
#    3028     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    1888         elif name in self._class_to_module.keys():
#    1889             module = self._get_module(self._class_to_module[name])
# -> 1890             value = getattr(module, name)
#    1891         else:
#    1892             raise AttributeError(f"module {self.__name__} has no attribute {name}")
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/file_utils.py in __getattr__(self, name)
#    1887             value = self._get_module(name)
#    1888         elif name in self._class_to_module.keys():
# -> 1889             module = self._get_module(self._class_to_module[name])
#    1890             value = getattr(module, name)
#    1891         else:
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/bert/__init__.py in _get_module(self, module_name)
#     151
#     152         def _get_module(self, module_name: str):
# --> 153             return importlib.import_module("." + module_name, self.__name__)
#     154
#     155     sys.modules[__name__] = _LazyModule(__name__, _import_structure)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/__init__.py in import_module(name, package)
#     125                 break
#     126             level += 1
# --> 127     return _bootstrap._gcd_import(name[level:], package, level)
#     128
#     129
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap.py in _gcd_import(name, package, level)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap.py in _load_unlocked(spec)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap_external.py in exec_module(self, module)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/importlib/_bootstrap.py in _call_with_frames_removed(f, *args, **kwds)
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/models/bert/tokenization_bert.py in <module>
#      21 from typing import List, Optional, Tuple
#      22
# ---> 23 from ...tokenization_utils import PreTrainedTokenizer, _is_control, _is_punctuation, _is_whitespace
#      24 from ...utils import logging
#      25
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/tokenization_utils.py in <module>
#      24
#      25 from .file_utils import PaddingStrategy, TensorType, add_end_docstrings
# ---> 26 from .tokenization_utils_base import (
#      27     ENCODE_KWARGS_DOCSTRING,
#      28     ENCODE_PLUS_ADDITIONAL_KWARGS_DOCSTRING,
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/transformers/tokenization_utils_base.py in <module>
#      67
#      68 if is_tokenizers_available():
# ---> 69     from tokenizers import AddedToken
#      70     from tokenizers import Encoding as EncodingFast
#      71 else:
#
# ~/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/__init__.py in <module>
#      77
#      78
# ---> 79 from .tokenizers import (
#      80     Tokenizer,
#      81     Encoding,
#
# ImportError: dlopen(/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so, 2): no suitable image found.  Did find:
# 	/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so: mach-o, but wrong architecture
# 	/Users/rainism/miniforge3/envs/tensorflow/lib/python3.8/site-packages/tokenizers/tokenizers.cpython-38-darwin.so: mach-o, but wrong architecture
